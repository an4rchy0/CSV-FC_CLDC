# %%
import pandas as pd

try :
    df = pd.read_csv('./Data/2021socio_economic_indonesia.csv')
    print(df)
except Exception as e:
    print(e)
# Out:
#     province     cities_reg  poorpeople_percentage  reg_gdp  life_exp  \
# 0       Aceh       Simeulue                  18.98    2.275    65.240
# 1       Aceh   Aceh Singkil                  20.36    2.425    67.355
# 2       Aceh   Aceh Selatan                  13.18    5.531    64.360
# 3       Aceh  Aceh Tenggara                  13.41    5.063    68.155
# 4       Aceh     Aceh Timur                  14.45   10.616    68.705
# ..       ...            ...                    ...      ...       ...
# 509    Papua         Puncak                  36.26    1.438    66.060
# 510    Papua        Dogiyai                  28.81    1.356    65.845
# 511    Papua     Intan Jaya                  41.66    1.274    65.580
# 512    Papua         Deiyai                  40.59    1.439    65.355
# 513    Papua  Kota Jayapura                  11.39   32.207    70.455
#
#      avg_schooltime  exp_percap
# 0              9.48        7148
# 1              8.68        8776
# 2              8.88        8180
# 3              9.67        8030
# 4              8.21        8577
# ..              ...         ...
# 509            2.16        5412
# 510            4.94        5415
# 511            3.09        5328
# 512            3.25        4673
# 513           11.57       14937
#
# [514 rows x 7 columns]

# %% [markdown]
# Clear data

# %%
missing_values = df.isnull().sum()
print(missing_values)

df = pd.DataFrame(df)
# Out:
# province                 0
# cities_reg               0
# poorpeople_percentage    0
# reg_gdp                  0
# life_exp                 0
# avg_schooltime           0
# exp_percap               0
# dtype: int64

# %% [markdown]
# Menyortir Pendapatan GDP mulai dari terendah: ds1 (data sortir1)

# %%
ds1 = df.sort_values(by='exp_percap')
ds1
# Out:
#           province            cities_reg  poorpeople_percentage  reg_gdp  \
# 505          Papua                 Nduga                  37.18    1.271
# 506          Papua            Lanny Jaya                  38.73    1.935
# 507          Papua      Mamberamo Tengah                  36.76    1.215
# 504          Papua        Mamberamo Raya                  28.78    1.725
# 508          Papua                Yalimo                  33.25    1.286
# ..             ...                   ...                    ...      ...
# 159    DKI Jakarta    Kota Jakarta Utara                   7.24  497.299
# 226  DI Yogyakarta       Kota Yogyakarta                   7.69   35.768
# 281           Bali         Kota Denpasar                   2.96   49.583
# 158    DKI Jakarta    Kota Jakarta Barat                   4.31  469.918
# 155    DKI Jakarta  Kota Jakarta Selatan                   3.56  644.572
#
#      life_exp  avg_schooltime  exp_percap
# 505    55.370            1.42        3976
# 506    66.015            3.43        4393
# 507    63.750            3.33        4487
# 504    57.990            5.87        4603
# 508    65.385            3.01        4664
# ..        ...             ...         ...
# 159    73.330           10.81       18762
# 226    74.660           11.72       18801
# 281    74.880           11.48       19598
# 158    73.655           10.78       20801
# 155    74.225           11.64       23888
#
# [514 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
for pr, d in df.groupby('poorpeople_percentage'):
    ax.scatter(d['cities_reg'], d['poorpeople_percentage'], label=pr)

plt.title('Poor Region Rank')
plt.xlabel('Cities Region')
plt.ylabel('Poor Percentage (%)')
plt.grid(True)
ax.tick_params(axis='x', labelsize=10)
plt.xticks(rotation=90)
plt.show()

# %%
import numpy as np
import sklearn
from sklearn import preprocessing

x_train = np.array(df[['reg_gdp', 'life_exp', 'avg_schooltime']])
y_train = np.array(df['poorpeople_percentage'])

lb = preprocessing.LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_train = y_train.flatten()

print(f'x_training : \n {x_train}')
print(f'y_training : \n {y_train}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 9
#       6 y_train = np.array(df['poorpeople_percentage'])
#       8 lb = preprocessing.LabelBinarizer()
# ----> 9 y_train = lb.fit_transform(y_train)
#      10 y_train = y_train.flatten()
#      12 print(f'x_training : \n {x_train}')
#
# File c:\Users\arc\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File c:\Users\arc\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_label.py:329, in LabelBinarizer.fit_transform(self, y)
#     309 def fit_transform(self, y):
#     310     """Fit label binarizer/transform multi-class labels to binary labels.
#     311
#     312     The output of transform is sometimes referred to as
#    (...)
#     327         will be of CSR format.
#     328     """
# --> 329     return self.fit(y).transform(y)
#
# File c:\Users\arc\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\arc\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_label.py:306, in LabelBinarizer.fit(self, y)
#     303     raise ValueError("y has 0 samples: %r" % y)
#     305 self.sparse_input_ = sp.issparse(y)
# --> 306 self.classes_ = unique_labels(y)
#     307 return self
#
# File c:\Users\arc\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\multiclass.py:104, in unique_labels(*ys)
#     102 _unique_labels = _FN_UNIQUE_LABELS.get(label_type, None)
#     103 if not _unique_labels:
# --> 104     raise ValueError("Unknown label type: %s" % repr(ys))
#     106 if is_array_api_compliant:
#     107     # array_api does not allow for mixed dtypes
#     108     unique_ys = xp.concat([_unique_labels(y) for y in ys])
#
# ValueError: Unknown label type: (array([18.98, 20.36, 13.18, 13.41, 14.45, 15.26, 18.81, 14.05, 19.59,
#        13.25, 17.43, 16.34, 19.64, 13.34, 18.23, 13.23, 19.16, 19.55,
#         7.61, 15.32, 10.96, 11.16, 17.65, 16.82,  9.49,  8.8 , 12.67,
#         9.72,  8.99,  8.74,  9.35,  8.81,  8.31,  8.79,  4.01, 10.12,
#        16.92,  9.65,  9.35, 12.68,  8.3 , 12.38,  9.92,  8.69,  8.53,
#        10.02, 25.66, 26.42, 12.33, 13.4 ,  8.52, 10.3 ,  8.34,  5.81,
#         7.53, 16.45, 14.84,  7.92,  8.01,  6.8 ,  4.54,  7.22,  6.85,
#         7.29,  7.48,  7.52,  6.67,  7.51,  4.94,  3.12,  2.38,  5.92,
#         5.14,  6.16,  4.38,  8.97,  6.18,  6.18,  9.63,  5.18,  7.82,
#        10.4 ,  6.64,  7.18, 25.68,  2.83,  3.42,  7.71,  9.11,  8.87,
#        10.05,  4.53, 11.39, 10.75,  6.68,  6.23,  9.02,  3.41, 12.62,
#        14.68, 12.32, 16.46, 13.89, 15.84, 10.75, 11.12, 10.6 , 13.82,
#        13.35, 12.91, 20.11, 11.34, 12.2 ,  9.4 , 13.23, 18.16, 15.85,
#        11.61, 18.62, 18.72, 11.93, 12.  , 14.83,  9.68, 17.89, 12.82,
#        11.81, 14.19, 15.08, 11.99, 19.63, 13.09,  9.67, 15.11, 10.11,
#         7.54,  8.32, 14.81,  9.11,  8.93,  4.81,  7.15,  2.75,  5.13,
#         3.69,  7.2 ,  4.76,  6.85,  6.42,  4.95, 13.93,  7.09,  5.05,
#         9.57, 15.06,  3.56,  4.28,  4.94,  4.31,  7.24,  8.13,  7.7 ,
#        11.18,  7.15, 10.65, 11.15,  7.97, 13.1 , 12.3 , 12.33, 10.71,
#        13.04, 10.03,  8.83,  8.95,  5.21, 11.3 ,  9.65,  7.24,  8.25,
#         4.37, 10.03,  4.74,  2.58,  5.35, 13.13,  7.11, 11.67, 13.66,
#        16.24, 16.23, 17.83, 12.4 , 17.67, 11.91, 10.62, 13.49,  8.23,
#        11.55, 10.68, 13.83, 12.74, 12.39, 15.8 , 10.21,  7.6 ,  7.44,
#        12.92,  7.82, 10.17, 10.24,  9.68, 10.57, 16.56,  8.6 , 17.43,
#         7.75,  9.4 ,  5.14,  4.56,  7.59,  8.12, 18.38, 14.04, 17.69,
#         8.64,  7.69, 15.11, 10.26, 12.14,  7.51,  9.65, 11.64, 10.5 ,
